# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv("googleplaystore_a.csv")

# %%
df.head(50)
# Out:
#                                                   App           Category  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook     ART_AND_DESIGN
# 1                                 Coloring book moana     ART_AND_DESIGN
# 2   U Launcher Lite 鈥?FREE Live Cool Themes, Hide ...     ART_AND_DESIGN
# 3                               Sketch - Draw & Paint     ART_AND_DESIGN
# 4               Pixel Draw - Number Art Coloring Book     ART_AND_DESIGN
# 5                          Paper flowers instructions     ART_AND_DESIGN
# 6             Smoke Effect Photo Maker - Smoke Editor     ART_AND_DESIGN
# 7                                    Infinite Painter     ART_AND_DESIGN
# 8                                Garden Coloring Book     ART_AND_DESIGN
# 9                       Kids Paint Free - Drawing Fun     ART_AND_DESIGN
# 10                            Text on Photo - Fonteee     ART_AND_DESIGN
# 11            Name Art Photo Editor - Focus n Filters     ART_AND_DESIGN
# ...

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite 鈥?FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# ...

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1466
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
impute = SimpleImputer(missing_values=np.nan,strategy='mean')
impute.fit(df.iloc[:,2:3].values)
df.iloc[:,2:3]= impute.transform(df.iloc[:,2:3].values)

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite 鈥?FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10774                                   Sya9a Maroc - FR               FAMILY
# 10775                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10776                             Parkinson Exercices FR              MEDICAL
# 10777                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10778      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       2
# dtype: int64

# %%
df=df.dropna()

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite 鈥?FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10774                                   Sya9a Maroc - FR               FAMILY
# 10775                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10776                             Parkinson Exercices FR              MEDICAL
# 10777                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10778      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %% [markdown]
# ## How many Free apps are there in ART_AND_DESIGN?

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite 鈥?FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10774                                   Sya9a Maroc - FR               FAMILY
# 10775                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10776                             Parkinson Exercices FR              MEDICAL
# 10777                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10778      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite 鈥?FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design     7-Jan-18               1.0.0  4.0.3 and up
# ...

# %%
df.values
# Out:
# array([['Photo Editor & Candy Camera & Grid & ScrapBook',
#         'ART_AND_DESIGN', 4.1, ..., '7-Jan-18', '1.0.0', '4.0.3 and up'],
#        ['Coloring book moana', 'ART_AND_DESIGN', 3.9, ..., '15-Jan-18',
#         '2.0.0', '4.0.3 and up'],
#        ['U Launcher Lite 鈥?FREE Live Cool Themes, Hide Apps',
#         'ART_AND_DESIGN', 4.7, ..., '1-Aug-18', '1.2.4', '4.0.3 and up'],
#        ...,
#        ['Parkinson Exercices FR', 'MEDICAL', 4.191592397723611, ...,
#         '20-Jan-17', '1', '2.2 and up'],
#        ['The SCP Foundation DB fr nn5n', 'BOOKS_AND_REFERENCE', 4.5, ...,
#         '19-Jan-15', 'Varies with device', 'Varies with device'],
#        ['iHoroscope - 2018 Daily Horoscope & Astrology', 'LIFESTYLE',
#         4.5, ..., '25-Jul-18', 'Varies with device',
#         'Varies with device']], dtype=object)

# %%
df.values.shape
# Out:
# (10768, 13)

# %%
df=df.values

# %%
df[0]
# Out:
# array(['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN',
#        4.1, 159, '19M', '10,000+', 'Free', '0', 'Everyone',
#        'Art & Design', '7-Jan-18', '1.0.0', '4.0.3 and up'], dtype=object)

# %%
df[1]
# Out:
# array(['Coloring book moana', 'ART_AND_DESIGN', 3.9, 967, '14M',
#        '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play',
#        '15-Jan-18', '2.0.0', '4.0.3 and up'], dtype=object)

# %%
c=0
for i in df:
    if(i[1]=='ART_AND_DESIGN' and i[6]=='Free'):
        c+=1;

print("There are ",c,"Free ART_AND_DESIGN APPS.")
# Out:
# There are  61 Free ART_AND_DESIGN APPS.

# %% [markdown]
# ## How many Paid apps are there in ART_AND_DESIGN?

# %%
c=0
for i in df:
    if(i[1]=='ART_AND_DESIGN' and i[6]=='Paid'):
        c+=1;

print("There are ",c,"Paid ART_AND_DESIGN APPS.")
# Out:
# There are  3 Paid ART_AND_DESIGN APPS.

# %% [markdown]
# ## How many apps are there in ART_AND_DESIGN with Rating more than 4.5?

# %%
c=0

for i in df:
    if(i[1]=='ART_AND_DESIGN' and i[2] >4.5):
        c+=1
print("There are ",c," ART_AND_DESIGN apps with Rating more than 4.5")
# Out:
# There are  22  ART_AND_DESIGN apps with Rating more than 4.5

# %% [markdown]
# ## List all the free apps with Rating more than '4.5' and Category is 'Family'

# %%
c=0
for i in df:
    if(i[1]=='FAMILY' and i[2]>4.5):
        print(i[0])
        c+=1
print("There are",c," Such apps.")
# Out:
# Super ABC! Learning games for kids! Preschool apps
# Candy Pop Story
# Dog Run - Pet Dog Simulator
# Puzzle Kids - Animals Shapes and Jigsaw Puzzles
# No. Color - Color by Number, Number Coloring
# Garden Fruit Legend
# Piano Kids - Music & Songs
# Duolingo: Learn Languages Free
# Super ABC! Learning games for kids! Preschool apps
# Drawing for Kids Learning Games for Toddlers age 3
# Baby ABC in box! Kids alphabet games for toddlers!
# Henry Danger Crime Warp
# Fruit Cube Blast
# Toddler Kids Puzzles PUZZINGO
# Fuzzy Seasons: Animal Forest
# Dog Run - Pet Dog Simulator
# My Oasis - Calming and Relaxing Idle Clicker Game
# Ninja Dash - Ronin Jump RPG
# Monster High鈩?Minis Mania
# Monica Toy TV
# Sworkit Kids - Fitness Meets Fun
# Toca Life: City
# Crazy Colors: Bubbles Matching
# Pino chess
# Children Educational Game Full
# Hactar Go
# World Racers family board game
# Lanterns: The Harvest Festival
# Tsuro - The Game of the Path
# Avokiddo Emotions
# Avokiddo Emotions
# ...

# %% [markdown]
# ## How many free apps are there in art and design?

# %%
df = pd.read_csv("googleplaystore_a.csv")

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite 鈥?FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10774                                   Sya9a Maroc - FR               FAMILY
# 10775                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10776                             Parkinson Exercices FR              MEDICAL
# 10777                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10778      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df[df['Category']=='ART_AND_DESIGN']
# Out:
#                                                     App        Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                   Coloring book moana  ART_AND_DESIGN
# 2     U Launcher Lite 鈥?FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint  ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                 ...             ...
# 7128                            Easy DIY CD Craft Ideas  ART_AND_DESIGN
# 8627                                       Dp for girls  ART_AND_DESIGN
# 8660             Name Art DP - Focus n Filter Text 2018  ART_AND_DESIGN
# 8819                             Test Application DT 02  ART_AND_DESIGN
# 8836            Spring flowers theme couleurs d t space  ART_AND_DESIGN
#
#       Rating  Reviews  Size     Installs  Type Price Content Rating  \
# ...

# %%
df_pr = df[df['Category']=='ART_AND_DESIGN']
print(len(df_pr[df_pr['Type']=='Free']))
# Out:
# 62

# %% [markdown]
# ## How many free apps are there in ART_AND_DESIGN with rating more than 4.5?

# %%
df_pr = df[df['Category']=='ART_AND_DESIGN']
print(len(df_pr[df_pr['Rating'] >4.5]))
# Out:
# 22

# %% [markdown]
# ## How many apps are there in FAMILY with Rating more than  4.5 and are Free?

# %%
df_pr = df[df['Category']=='FAMILY']
df_pr1=df_pr[df_pr['Rating']>4.5]             # we can write simply
                                              # df_pr1[df_pr[df_pr['Rating']>4.5]['Type']=='Free']
df_pr1[df_pr1['Type']=='Free']
# Out:
#                                                      App Category  Rating  \
# 2007   Super ABC! Learning games for kids! Preschool ...   FAMILY     4.6
# 2010                                     Candy Pop Story   FAMILY     4.7
# 2016                         Dog Run - Pet Dog Simulator   FAMILY     4.7
# 2019     Puzzle Kids - Animals Shapes and Jigsaw Puzzles   FAMILY     4.6
# 2027        No. Color - Color by Number, Number Coloring   FAMILY     4.8
# ...                                                  ...      ...     ...
# 10630                                             Pin-fo   FAMILY     4.6
# 10739                                Fr Ignacio Outreach   FAMILY     4.9
# 10747              Castle Clash: RPG War and Strategy FR   FAMILY     4.7
# 10758                                    Fr. Daoud Lamei   FAMILY     5.0
# 10775                   Fr. Mike Schmitz Audio Teachings   FAMILY     5.0
#
#        Reviews  Size     Installs  Type Price Content Rating  \
# ...

# %% [markdown]
# ## List all the free apps with rating more than 4.5 and Category is 'Family'?

# %%
df = pd.read_csv("googleplaystore_a.csv")

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite 鈥?FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10774                                   Sya9a Maroc - FR               FAMILY
# 10775                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10776                             Parkinson Exercices FR              MEDICAL
# 10777                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10778      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_pr=df[df['Type']=='Free']
df_pr1=df_pr[df_pr['Rating']>4.5]
df_pr1[df_pr1['Category']=='FAMILY']
# Out:
#                                                      App Category  Rating  \
# 2007   Super ABC! Learning games for kids! Preschool ...   FAMILY     4.6
# 2010                                     Candy Pop Story   FAMILY     4.7
# 2016                         Dog Run - Pet Dog Simulator   FAMILY     4.7
# 2019     Puzzle Kids - Animals Shapes and Jigsaw Puzzles   FAMILY     4.6
# 2027        No. Color - Color by Number, Number Coloring   FAMILY     4.8
# ...                                                  ...      ...     ...
# 10630                                             Pin-fo   FAMILY     4.6
# 10739                                Fr Ignacio Outreach   FAMILY     4.9
# 10747              Castle Clash: RPG War and Strategy FR   FAMILY     4.7
# 10758                                    Fr. Daoud Lamei   FAMILY     5.0
# 10775                   Fr. Mike Schmitz Audio Teachings   FAMILY     5.0
#
#        Reviews  Size     Installs  Type Price Content Rating  \
# ...

# %%
df_pr1[df_pr1['Category']=='FAMILY']['App']
# Out:
# 2007     Super ABC! Learning games for kids! Preschool ...
# 2010                                       Candy Pop Story
# 2016                           Dog Run - Pet Dog Simulator
# 2019       Puzzle Kids - Animals Shapes and Jigsaw Puzzles
# 2027          No. Color - Color by Number, Number Coloring
#                                ...
# 10630                                               Pin-fo
# 10739                                  Fr Ignacio Outreach
# 10747                Castle Clash: RPG War and Strategy FR
# 10758                                      Fr. Daoud Lamei
# 10775                     Fr. Mike Schmitz Audio Teachings
# Name: App, Length: 312, dtype: object

# %%
result = df_pr1[df_pr1['Category']=='FAMILY'].values

for i in result:
    print(i[0])
# Out:
# Super ABC! Learning games for kids! Preschool apps
# Candy Pop Story
# Dog Run - Pet Dog Simulator
# Puzzle Kids - Animals Shapes and Jigsaw Puzzles
# No. Color - Color by Number, Number Coloring
# Garden Fruit Legend
# Piano Kids - Music & Songs
# Duolingo: Learn Languages Free
# Super ABC! Learning games for kids! Preschool apps
# Drawing for Kids Learning Games for Toddlers age 3
# Baby ABC in box! Kids alphabet games for toddlers!
# Henry Danger Crime Warp
# Fruit Cube Blast
# Toddler Kids Puzzles PUZZINGO
# Fuzzy Seasons: Animal Forest
# Dog Run - Pet Dog Simulator
# My Oasis - Calming and Relaxing Idle Clicker Game
# Ninja Dash - Ronin Jump RPG
# Monster High鈩?Minis Mania
# Monica Toy TV
# Sworkit Kids - Fitness Meets Fun
# Crazy Colors: Bubbles Matching
# Pino chess
# Duolingo: Learn Languages Free
# Animal Jam - Play Wild!
# Dog Sim Online: Raise a Family
# Color by Number - Draw Sandbox Pixel Art
# Build a Bridge!
# Find a Way: Addictive Puzzle
# CompTIA Exam Training
# ...

# %% [markdown]
# ## Name the apps that are in ART_AND_DESIGN with rating more than 4.52 in ascending order wrt Ratings?

# %%
df = pd.read_csv("googleplaystore_a.csv")

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite 鈥?FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10774                                   Sya9a Maroc - FR               FAMILY
# 10775                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10776                             Parkinson Exercices FR              MEDICAL
# 10777                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10778      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1466
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
impute= SimpleImputer(missing_values= np.nan,strategy='mean')
impute.fit(df.iloc[:,2:3].values)
df.iloc[:,2:3]=impute.transform(df.iloc[:,2:3].values)
df.iloc[:,2:3]
# Out:
#          Rating
# 0      4.100000
# 1      3.900000
# 2      4.700000
# 3      4.500000
# 4      4.300000
# ...         ...
# 10774  4.500000
# 10775  5.000000
# 10776  4.191592
# 10777  4.500000
# 10778  4.500000
#
# [10779 rows x 1 columns]

# %%
impute= SimpleImputer(missing_values=np.nan,strategy='most_frequent')
impute.fir(df.iloc[:,])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [84], in <cell line: 2>()
#       1 impute= SimpleImputer(missing_values=np.nan,strategy='most_frequent')
# ----> 2 impute.fir(df.iloc[:,])
#
# AttributeError: 'SimpleImputer' object has no attribute 'fir'

# %%
df_pr = df[df['Category']=='ART_AND_DESIGN']
df_pr = df_pr[df_pr['Rating'] > 4.5]
df_pr
# Out:
#                                                     App        Category  \
# 2     U Launcher Lite 鈥?FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 9                         Kids Paint Free - Drawing Fun  ART_AND_DESIGN
# 13                                Mandala Coloring Book  ART_AND_DESIGN
# 16         Photo Designer - Write your name with shapes  ART_AND_DESIGN
# 19                                         ibis Paint X  ART_AND_DESIGN
# 22              Superheroes Wallpapers | 4K Backgrounds  ART_AND_DESIGN
# 24                          HD Mickey Minnie Wallpapers  ART_AND_DESIGN
# 25                           Harley Quinn wallpapers HD  ART_AND_DESIGN
# 26                        Colorfit - Drawing & Coloring  ART_AND_DESIGN
# 34                                      I Creative Idea  ART_AND_DESIGN
# 36       UNICORN - Color By Number & Pixel Art Coloring  ART_AND_DESIGN
# 38                       PIP Camera - PIP Collage Maker  ART_AND_DESIGN
# ...

# %%
df_pr.sort_values(by = 'Rating',ascending=True)
# Out:
#                                                     App        Category  \
# 13                                Mandala Coloring Book  ART_AND_DESIGN
# 19                                         ibis Paint X  ART_AND_DESIGN
# 46    Install images with music to make video withou...  ART_AND_DESIGN
# 2     U Launcher Lite 鈥?FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 4732     X Launcher Prime: With OS Style Theme & No Ads  ART_AND_DESIGN
# 4723  X Launcher Pro: PhoneX Theme, OS11 Control Center  ART_AND_DESIGN
# 4717  X Launcher: With OS11 Style Theme & Control Ce...  ART_AND_DESIGN
# 45    Canva: Poster, banner, card maker & graphic de...  ART_AND_DESIGN
# 38                       PIP Camera - PIP Collage Maker  ART_AND_DESIGN
# 36       UNICORN - Color By Number & Pixel Art Coloring  ART_AND_DESIGN
# 26                        Colorfit - Drawing & Coloring  ART_AND_DESIGN
# 24                          HD Mickey Minnie Wallpapers  ART_AND_DESIGN
# ...

# %% [markdown]
# ## Name the apps that are in ART_AND_DESIGN with rating more than 4.52 in descending order wrt Ratings?

# %%
df_pr.sort_values(by = 'Rating',ascending=False)
# Out:
#                                                     App        Category  \
# 8836            Spring flowers theme couleurs d t space  ART_AND_DESIGN
# 6884               Fantasy theme dark bw black building  ART_AND_DESIGN
# 5220                            AJ Styles HD Wallpapers  ART_AND_DESIGN
# 4727  X Launcher Pro - IOS Style Theme & Control Center  ART_AND_DESIGN
# 25                           Harley Quinn wallpapers HD  ART_AND_DESIGN
# 3958                                  Cardi B Wallpaper  ART_AND_DESIGN
# 9                         Kids Paint Free - Drawing Fun  ART_AND_DESIGN
# 4732     X Launcher Prime: With OS Style Theme & No Ads  ART_AND_DESIGN
# 4723  X Launcher Pro: PhoneX Theme, OS11 Control Center  ART_AND_DESIGN
# 4717  X Launcher: With OS11 Style Theme & Control Ce...  ART_AND_DESIGN
# 45    Canva: Poster, banner, card maker & graphic de...  ART_AND_DESIGN
# 2     U Launcher Lite 鈥?FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# ...

# %%
df_pr.sort_values(by = 'Rating',ascending=False).head()  #Top 5
# Out:
#                                                     App        Category  \
# 8836            Spring flowers theme couleurs d t space  ART_AND_DESIGN
# 6884               Fantasy theme dark bw black building  ART_AND_DESIGN
# 5220                            AJ Styles HD Wallpapers  ART_AND_DESIGN
# 4727  X Launcher Pro - IOS Style Theme & Control Center  ART_AND_DESIGN
# 25                           Harley Quinn wallpapers HD  ART_AND_DESIGN
#
#       Rating  Reviews  Size Installs  Type   Price Content Rating  \
# 8836     5.0        1  2.9M     100+  Free       0       Everyone
# 6884     4.8       41  1.9M   5,000+  Free       0       Everyone
# 5220     4.8       48   25M   5,000+  Free       0       Everyone
# 4727     4.8     1216  8.6M  10,000+  Paid  $1.99        Everyone
# 25       4.8      192  6.0M  10,000+  Free       0       Everyone
#
#             Genres Last Updated Current Ver Android Ver
# 8836  Art & Design    18-Apr-18       1.0.2  4.0 and up
# ...

# %% [markdown]
# ## Name the apps that are in ART_AND_DESIGN in descending order wrt Reviews?

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite 鈥?FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10774                                   Sya9a Maroc - FR               FAMILY
# 10775                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10776                             Parkinson Exercices FR              MEDICAL
# 10777                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10778      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_pr = df[df['Category'] == 'ART_AND_DESIGN']
df_pr.sort_values(by= 'Reviews' ,ascending =False)
# Out:
#                                                     App        Category  \
# 4216                         Textgram - write on photos  ART_AND_DESIGN
# 42                           Textgram - write on photos  ART_AND_DESIGN
# 19                                         ibis Paint X  ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint  ART_AND_DESIGN
# 18                        FlipaClip - Cartoon animation  ART_AND_DESIGN
# ...                                                 ...             ...
# 5224  AJ Styles Wallpaper 2018 - AJ Styles HD Wallpaper  ART_AND_DESIGN
# 4169                                          氐賵乇 丨乇賮 H  ART_AND_DESIGN
# 7128                            Easy DIY CD Craft Ideas  ART_AND_DESIGN
# 8836            Spring flowers theme couleurs d t space  ART_AND_DESIGN
# 8819                             Test Application DT 02  ART_AND_DESIGN
#
#         Rating  Reviews                Size     Installs  Type Price  \
# ...

# %% [markdown]
# ##  Which category is having maximum average rating?

# %%
df['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
df.groupby('Category').mean()['Rating'].sort_values(ascending=False)
# Out:
# Category
# EDUCATION              4.387767
# EVENTS                 4.363129
# ART_AND_DESIGN         4.350381
# BOOKS_AND_REFERENCE    4.310625
# PERSONALIZATION        4.306898
# PARENTING              4.301965
# GAME                   4.282119
# HEALTH_AND_FITNESS     4.266460
# BEAUTY                 4.260519
# SHOPPING               4.254145
# SOCIAL                 4.247788
# WEATHER                4.239526
# SPORTS                 4.218108
# PRODUCTIVITY           4.207986
# HOUSE_AND_HOME         4.196581
# FAMILY                 4.192132
# AUTO_AND_VEHICLES      4.190578
# PHOTOGRAPHY            4.190565
# MEDICAL                4.189741
# LIBRARIES_AND_DEMO     4.176570
# FOOD_AND_DRINK         4.170462
# COMMUNICATION          4.163741
# COMICS                 4.156607
# NEWS_AND_MAGAZINES     4.144213
# BUSINESS               4.144183
# FINANCE                4.138903
# ENTERTAINMENT          4.122973
# TRAVEL_AND_LOCAL       4.121132
# LIFESTYLE              4.112002
# ...

# %% [markdown]
# ## How many apps are there in each category in Descending order?

# %%
df.groupby('Category').count()['Type'].sort_values(ascending= False)
# Out:
# Category
# FAMILY                 1952
# GAME                   1135
# TOOLS                   836
# MEDICAL                 463
# BUSINESS                459
# PRODUCTIVITY            424
# PERSONALIZATION         387
# COMMUNICATION           386
# SPORTS                  384
# LIFESTYLE               378
# FINANCE                 366
# HEALTH_AND_FITNESS      339
# PHOTOGRAPHY             334
# SOCIAL                  295
# NEWS_AND_MAGAZINES      280
# SHOPPING                259
# TRAVEL_AND_LOCAL        257
# DATING                  232
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           148
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       84
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                59
# COMICS                   58
# ...

# %% [markdown]
# ## How many 'Free' apps are there in each category in Descending order?

# %%
df_pr =df[df['Type']=='Free']

df_pr.groupby('Category').count()['Type'].sort_values(ascending=False)
# Out:
# Category
# FAMILY                 1763
# GAME                   1053
# TOOLS                   759
# BUSINESS                445
# PRODUCTIVITY            396
# SPORTS                  360
# COMMUNICATION           359
# LIFESTYLE               359
# MEDICAL                 354
# FINANCE                 349
# HEALTH_AND_FITNESS      323
# PHOTOGRAPHY             312
# PERSONALIZATION         308
# SOCIAL                  292
# NEWS_AND_MAGAZINES      278
# SHOPPING                257
# TRAVEL_AND_LOCAL        245
# DATING                  225
# BOOKS_AND_REFERENCE     203
# VIDEO_PLAYERS           171
# EDUCATION               152
# ENTERTAINMENT           146
# MAPS_AND_NAVIGATION     132
# FOOD_AND_DRINK          125
# HOUSE_AND_HOME           88
# LIBRARIES_AND_DEMO       83
# AUTO_AND_VEHICLES        82
# WEATHER                  74
# EVENTS                   63
# ART_AND_DESIGN           62
# COMICS                   58
# PARENTING                57
# ...

# %% [markdown]
# ## How many 'Paid' apps are there in each category in Descending order?

# %%
df_pr =df[df['Type']=='Paid']

df_pr.groupby('Category').count()['Type'].sort_values(ascending=False)
# Out:
# Category
# FAMILY                 189
# MEDICAL                109
# GAME                    82
# PERSONALIZATION         79
# TOOLS                   77
# BOOKS_AND_REFERENCE     28
# PRODUCTIVITY            28
# COMMUNICATION           27
# SPORTS                  24
# PHOTOGRAPHY             22
# LIFESTYLE               19
# FINANCE                 17
# HEALTH_AND_FITNESS      16
# BUSINESS                14
# TRAVEL_AND_LOCAL        12
# WEATHER                  8
# DATING                   7
# MAPS_AND_NAVIGATION      5
# EDUCATION                4
# VIDEO_PLAYERS            4
# AUTO_AND_VEHICLES        3
# SOCIAL                   3
# ART_AND_DESIGN           3
# NEWS_AND_MAGAZINES       2
# PARENTING                2
# FOOD_AND_DRINK           2
# SHOPPING                 2
# ENTERTAINMENT            2
# LIBRARIES_AND_DEMO       1
# EVENTS                   1
# Name: Type, dtype: int64
